# %% [markdown]
# # Lecture 6 - Data  Visualisation - Solutions

# %% [markdown]
# ### Assignment 1.0
# Import Pandas, import the CSV <b>'weather_aus.csv'</b> file as you did in the previous assignment. Generate few visualisations to explore the dataset. Use the following plots to explore the data.
# 1. BoxPlot
# 2. Histogram
# 3. Scatter Plot
# 4. Correlation Matrix
#
# <b> Hint </b>
#
# The weather dataset contains weather data that belongs to many cities. So choose the weather data the belongs to a city (e.g. Canberra) and one of the data attributes (such as MinTemp or MaxTemp etc.) for generating the visualisations. For example, the following code selects the MinTemp and MaxTemp of weather data that belongs to Canberra.
#
# ```python
# import matplotlib.pyplot as plt
#
# can_min_temp = df.loc[df['Location'] == 'Canberra']['MinTemp']
#
# can_max_temp = df.loc[df['Location'] == 'Canberra']['MaxTemp']
#
# ```

# %% [markdown]
# ## Solution

# %%
#Let's import the libraries and look into the data at hand
import pandas as pd

# %%
df = pd.read_csv('weather_aus.csv')

# %%
df.head(100)
# Out:
#           Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 0   2008-12-01   Albury     13.4     22.9       0.6          NaN       NaN
# 1   2008-12-02   Albury      7.4     25.1       0.0          NaN       NaN
# 2   2008-12-03   Albury     12.9     25.7       0.0          NaN       NaN
# 3   2008-12-04   Albury      9.2     28.0       0.0          NaN       NaN
# 4   2008-12-05   Albury     17.5     32.3       1.0          NaN       NaN
# ..         ...      ...      ...      ...       ...          ...       ...
# 95  2009-03-07   Albury      8.3     27.9       0.0          NaN       NaN
# 96  2009-03-08   Albury     11.0     30.2       0.0          NaN       NaN
# 97  2009-03-09   Albury     13.8     31.8       0.0          NaN       NaN
# 98  2009-03-10   Albury     15.5     32.0       0.0          NaN       NaN
# 99  2009-03-11   Albury     18.4     30.5       1.2          NaN       NaN
#
# ...

# %%
df.columns??

# %%
df.columnsumns

# %%
df['Location'].value_counts
# Out:
# Canberra            3418
# Sydney              3337
# Perth               3193
# Darwin              3192
# Hobart              3188
# Brisbane            3161
# Adelaide            3090
# Bendigo             3034
# Townsville          3033
# AliceSprings        3031
# MountGambier        3030
# Launceston          3028
# Ballarat            3028
# Albany              3016
# Albury              3011
# MelbourneAirport    3009
# PerthAirport        3009
# Mildura             3007
# SydneyAirport       3005
# Nuriootpa           3002
# Sale                3000
# Watsonia            2999
# Tuggeranong         2998
# Portland            2996
# Woomera             2990
# Cobar               2988
# Cairns              2988
# Wollongong          2983
# GoldCoast           2980
# WaggaWagga          2976
# NorfolkIsland       2964
# Penrith             2964
# SalmonGums          2955
# Newcastle           2955
# CoffsHarbour        2953
# Witchcliffe         2952
# Richmond            2951
# ...

# %% [markdown]
# ### Choose the MinTemp of  Canberra and Sydney

# %%
can_min_temp = df.loc[df['Location'] == 'Canberra']['MinTemp']

syd_min_temp = df.loc[df['Location'] == 'Sydney']['MinTemp']

# %% [markdown]
# ### Boxplot to see the dispersion of temperature

# %%
import matplotlib.pyplot as plt

# %%
plt.boxplot(can_min_temp.dropna())
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2103de5b908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2103de67a08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2103de4ed48>],
#  'medians': [<matplotlib.lines.Line2D at 0x2103de6cb08>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2103de6cc08>],
#  'means': []}

# %%
can_max_temp = df.loc[df['Location'] == 'Canberra']['MaxTemp']

df2 = pd.DataFrame(can_max_temp)

df2.boxplot()

# %% [markdown]
# # Histogram

# %%
can_max_rainfall = df.loc[df['Location'] == 'Canberra']['Rainfall']

plt.hist(can_max_rainfall.dropna(), 20)
# Out:
# (array([3.032e+03, 1.560e+02, 7.800e+01, 5.100e+01, 2.300e+01, 1.900e+01,
#         1.400e+01, 7.000e+00, 6.000e+00, 6.000e+00, 0.000e+00, 1.000e+00,
#         4.000e+00, 2.000e+00, 2.000e+00, 0.000e+00, 0.000e+00, 0.000e+00,
#         0.000e+00, 1.000e+00]),
#  array([ 0.  ,  4.35,  8.7 , 13.05, 17.4 , 21.75, 26.1 , 30.45, 34.8 ,
#         39.15, 43.5 , 47.85, 52.2 , 56.55, 60.9 , 65.25, 69.6 , 73.95,
#         78.3 , 82.65, 87.  ]),
#  <a list of 20 Patch objects>)

# %% [markdown]
# # Scatter Plot

# %%
df[['MaxTemp','Rainfall']].describe()
# Out:
#              MaxTemp       Rainfall
# count  141871.000000  140787.000000
# mean       23.226784       2.349974
# std         7.117618       8.465173
# min        -4.800000       0.000000
# 25%        17.900000       0.000000
# 50%        22.600000       0.000000
# 75%        28.200000       0.800000
# max        48.100000     371.000000

# %%
df.plot.scatter(x='MaxTemp',y='Rainfall',c='DarkBlue')

# %% [markdown]
# # Correlation

# %%
df.corr()
# Out:
#                 MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  \
# MinTemp        1.000000  0.736267  0.104255     0.467261  0.072961
# MaxTemp        0.736267  1.000000 -0.074839     0.588915  0.469967
# Rainfall       0.104255 -0.074839  1.000000    -0.064549 -0.227525
# Evaporation    0.467261  0.588915 -0.064549     1.000000  0.366607
# Sunshine       0.072961  0.469967 -0.227525     0.366607  1.000000
# WindGustSpeed  0.177285  0.067690  0.133497     0.203001 -0.032831
# WindSpeed9am   0.176005  0.014680  0.086816     0.193936  0.008040
# WindSpeed3pm   0.175749  0.050800  0.057759     0.128895  0.056012
# Humidity9am   -0.234211 -0.505432  0.223725    -0.505890 -0.491603
# Humidity3pm    0.005999 -0.509270  0.255312    -0.392785 -0.629122
# Pressure9am   -0.451260 -0.332293 -0.168085    -0.269907  0.040959
# Pressure3pm   -0.461623 -0.427279 -0.126728    -0.293160 -0.020464
# Cloud9am       0.077625 -0.289865  0.198195    -0.185032 -0.675610
# ...
